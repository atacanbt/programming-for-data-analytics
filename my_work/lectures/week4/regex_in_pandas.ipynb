# %% [markdown]
# ## Using Regex in Pandas
# ---

# %%
# setup everything for the project
import pandas as pd
import re

datadir = '../datafiles/'
people_filename = datadir + 'people_100.csv'

# %%
# sanity check
people_df = pd.read_csv(people_filename)
people_df.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title
# 0  001-084-906-7849x73518    1945-10-26  Games developer
# 1       214.112.6044x4913    1910-03-24   Phytotherapist
# 2            277.609.7938    1992-07-02        Homeopath

# %%
people_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          100 non-null    int64
#  1   User Id        100 non-null    object
#  2   First Name     100 non-null    object
#  3   Last Name      100 non-null    object
#  4   Sex            100 non-null    object
#  5   Email          100 non-null    object
#  6   Phone          100 non-null    object
#  7   Date of birth  100 non-null    object
#  8   Job Title      100 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 7.2+ KB

# %% [markdown]
# ### Which method to use for extracting the domains from emails
#
# we already saw lastweek that we could use `split()` to get domains

# %%
people_df['domain'] = people_df['Email'].str.split('@').str[1]

people_df.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title       domain
# 0  001-084-906-7849x73518    1945-10-26  Games developer  example.net
# 1       214.112.6044x4913    1910-03-24   Phytotherapist  example.com
# 2            277.609.7938    1992-07-02        Homeopath  example.com

# %%
# Delete the column so we can look at it using regex
people_df.drop('domain1', axis=1, inplace=True)
people_df.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title       domain
# 0  001-084-906-7849x73518    1945-10-26  Games developer  example.net
# 1       214.112.6044x4913    1910-03-24   Phytotherapist  example.com
# 2            277.609.7938    1992-07-02        Homeopath  example.com

# %% [markdown]
# You could've used regular expression (and many different patterns would do the job). The string retuned by `str()` has a `replace()` method that can take regex, here, string method was used but it did not work

# %%
string = 'ann has €1000, john has €234'
new_string = string.replace(r'\d,', 'X', regex=True)
print(new_string)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 string = 'ann has €1000, john has €234'
# ----> 2 new_string = string.replace(r'\d,', 'X', regex=True)
#       3 print(new_string)
#
# TypeError: str.replace() takes no keyword arguments

# %%
# find/replace using regex
pattern = r'.*@'
people_df['domain'] = people_df['Email'].str.replace(pattern, '', regex=True)
people_df.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title       domain
# 0  001-084-906-7849x73518    1945-10-26  Games developer  example.net
# 1       214.112.6044x4913    1910-03-24   Phytotherapist  example.com
# 2            277.609.7938    1992-07-02        Homeopath  example.com

# %%
# and a more precise regex
pattern = r'.*@([\w\.]+\w{2,3})'
people_df['domain'] = people_df['Email'].str.replace(pattern, r'\1', regex=True)
people_df.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title       domain
# 0  001-084-906-7849x73518    1945-10-26  Games developer  example.net
# 1       214.112.6044x4913    1910-03-24   Phytotherapist  example.com
# 2            277.609.7938    1992-07-02        Homeopath  example.com

# %% [markdown]
# ## Phone Numbers
#
# Phone numbers record seems messy, there are hyphens, dots and some of the phone numbers has extensions.
# To clean them up;
# - Let's assume they are all phone numbers
# - let's take main numbers without extensions or other characters into another column
# - let's put the extensions into seperate column (numbers after the 'x')
#
# ### Main numbers
#
# If there is an 'x', we want the numbers before without any hyphens or dots.

# %%
# extansion pattern
extension_pattern = r'x\d*'
people_df['clean_phone'] = people_df['Phone'].str.replace(extension_pattern, '', regex=True)
people_df.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title       domain  \
# 0  001-084-906-7849x73518    1945-10-26  Games developer  example.net
# 1       214.112.6044x4913    1910-03-24   Phytotherapist  example.com
# 2            277.609.7938    1992-07-02        Homeopath  example.com
#
#         clean_phone
# 0  001-084-906-7849
# 1      214.112.6044
# 2      277.609.7938

# %%
#other characters, such as - or ., can be removed using the same method
othercharacters_pattern = r'[-\.]*'
people_df['clean_phone'] = people_df['clean_phone'].str.replace(othercharacters_pattern, '', regex=True)
people_df.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title       domain  \
# 0  001-084-906-7849x73518    1945-10-26  Games developer  example.net
# 1       214.112.6044x4913    1910-03-24   Phytotherapist  example.com
# 2            277.609.7938    1992-07-02        Homeopath  example.com
#
#      clean_phone
# 0  0010849067849
# 1     2141126044
# 2     2776097938

# %%
# we should add the country code to the phone number which is +1 for the US
prefix_pattern = r'^([^\+0](.*))'
people_df['clean_phone'] = people_df['clean_phone'].str.replace(prefix_pattern, r'+1\1', regex=True)
people_df.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title       domain  \
# 0  001-084-906-7849x73518    1945-10-26  Games developer  example.net
# 1       214.112.6044x4913    1910-03-24   Phytotherapist  example.com
# 2            277.609.7938    1992-07-02        Homeopath  example.com
#
#      clean_phone
# 0  0010849067849
# 1   +12141126044
# 2   +12776097938

# %%
# lets replace 00 with + for international numbers
prefix_pattern = r'^00(.*)'
people_df['clean_phone'] = people_df['clean_phone'].str.replace(prefix_pattern, r'+\1', regex=True)
people_df.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title       domain  \
# 0  001-084-906-7849x73518    1945-10-26  Games developer  example.net
# 1       214.112.6044x4913    1910-03-24   Phytotherapist  example.com
# 2            277.609.7938    1992-07-02        Homeopath  example.com
#
#     clean_phone
# 0  +10849067849
# 1  +12141126044
# 2  +12776097938

# %%
# The Extensions

extension_pattern = r'^.*x'
people_df['extension'] = people_df['Phone'].str.replace(extension_pattern, '', regex=True)
people_df.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title       domain  \
# 0  001-084-906-7849x73518    1945-10-26  Games developer  example.net
# 1       214.112.6044x4913    1910-03-24   Phytotherapist  example.com
# 2            277.609.7938    1992-07-02        Homeopath  example.com
#
#     clean_phone     extension
# 0  +10849067849         73518
# 1  +12141126044          4913
# 2  +12776097938  277.609.7938

# %%
# above returns whole number on 3rd line
# let's use `str.extract()` instead
extension_pattern = r'x(\d+)'
people_df['extension'] = people_df['Phone'].str.extract(extension_pattern)
people_df.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title       domain  \
# 0  001-084-906-7849x73518    1945-10-26  Games developer  example.net
# 1       214.112.6044x4913    1910-03-24   Phytotherapist  example.com
# 2            277.609.7938    1992-07-02        Homeopath  example.com
#
#     clean_phone extension
# 0  +10849067849     73518
# 1  +12141126044      4913
# 2  +12776097938       NaN

# %%
# Filter
# you can filter rows in pandas based on a regular expression. 

people_df[people_df['Phone'].str.contains(r'^\+|^00')]
# Out:
#     Index          User Id First Name   Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby     Terrell    Male
# 5       6  bfDD7CDEF5D865B       Erin         Day    Male
# 6       7  bE9EEf34cB72AF7  Katherine        Buck  Female
# 7       8  2EFC6A4e77FaEaC    Ricardo      Hinton    Male
# 9      10  8e4FB470FE19bF0     Isaiah       Downs    Male
# 14     15  1F0B7D65A00DAF9    Crystal      Farmer    Male
# 15     16  50Bb061cB30B461     Thomas      Knight  Female
# 19     20  88473e15D5c3cD0      Jared    Mitchell  Female
# 22     23  cBbBcA0FCA3C4Bc      Randy      Barnes    Male
# 23     24  f1f89173353aD90     Janice      Rhodes  Female
# 28     29  66F096D36Ebae11       Judy     Buckley    Male
# 30     31  5d2feAfbdCAA6B5     Isaiah     Camacho  Female
# 32     33  8Ef7DBfcaB02b6B     Bonnie     Andrews  Female
# 33     34  6Dec5b5542F8ed8    Brandon     Schmidt  Female
# 37     38  ACcde95AAe3e6cC       Gene        Rich  Female
# 41     42  CEFA7BBCef013AE       Kirk       Walsh  Female
# 52     53  9F5DeD7aD228F5a    Beverly     Esparza  Female
# 54     55  60FdBFd5e7BE8fF      Debra       Payne  Female
# 73     weissbridget@example.com   +1-521-589-2387x48490    1974-06-08
# 80      johnathan72@example.org   001-386-469-3075x8030    1908-09-19
# 81            nhall@example.net    +1-376-865-2765x3351    1948-05-14
# 82        erikaball@example.net     +1-832-500-6044x475    2010-02-08
# 83     nixonvanessa@example.net   001-834-660-8312x9864    1961-11-11
# 84         melvin08@example.net        001-377-726-4229    1911-08-11
# 86  johnnyhendricks@example.net  001-698-651-0138x18588    1958-05-13
# 87          pbarron@example.net     +1-965-621-1157x345    1908-08-22
# 88       olsenmalik@example.net         +1-451-099-5805    1947-08-24
# 95          bmartin@example.org    001-095-524-2112x257    1954-07-30
# 96        latasha46@example.net        001-865-478-5157    1932-04-29
# 98   alexiscantrell@example.org    001-273-685-6932x092    2012-04-12
#
#                                Job Title       domain   clean_phone extension
# 0                        Games developer  example.net  +10849067849     73518
# 5               Waste management officer  example.org  +11716499856      5553
# 6                   Intelligence analyst  example.com  +17731516685     49162
# 7                         Hydrogeologist  example.com  +14476997998     88612
# 9                         Engineer, site  example.org  +15113721544      8206
# 14               Agricultural consultant  example.org  +10243775391       NaN
# 15       Sport and exercise psychologist  example.net  +13608800766       NaN
# 19                      Paediatric nurse  example.com  +19588496781       NaN
# 22  Outdoor activities/education manager  example.org  +19606297164     67214
# 23                     Drilling engineer  example.net  +12493149742      6996
# 28                   Art gallery manager  example.net  +16542081241     52830
# 30                     Food technologist  example.org  +15365443367       NaN
# 32                   Seismic interpreter  example.net  +12539872776      9161
# 33                  Engineer, biomedical  example.net  +13866731465       006
# 37                    Surveyor, quantity  example.org  +13568186604     89537
# 41                 Accounting technician  example.org  +18264965529      8661
# 52           Passenger transport manager  example.net  +13275788754      6771
# 54     Special educational needs teacher  example.org  +17315258400     52593
# 60                               Curator  example.org  +19516554798      6124
# 62                          Neurosurgeon  example.com  +17409370846      0087
# 64                  Biochemist, clinical  example.org  +10262656392       NaN
# 65              Scientist, water quality  example.org  +12446303792      4121
# 69                     Warehouse manager  example.com  +10966066454       067
# 70               Physiological scientist  example.org  +16955579948       485
# 73                   Structural engineer  example.com  +15215892387     48490
# 80                             Economist  example.org  +13864693075      8030
# 81                    Jewellery designer  example.net  +13768652765      3351
# 82            Contracting civil engineer  example.net  +18325006044       475
# 83             Higher education lecturer  example.net  +18346608312      9864
# 84           Lecturer, further education  example.net  +13777264229       NaN
# 86              Teacher, early years/pre  example.net  +16986510138     18588
# 87                 Travel agency manager  example.net  +19656211157       345
# 88              Technical sales engineer  example.net  +14510995805       NaN
# 95                     Software engineer  example.org  +10955242112       257
# 96                             Barrister  example.net  +18654785157       NaN
# 98                  Broadcast journalist  example.org  +12736856932       092
